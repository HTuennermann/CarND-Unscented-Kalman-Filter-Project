# %%
# %pylab inline
data =loadtxt("out.txt").T
plot([7.815]*len(data[~0]))
plot(data[~0])
title("NIS Radar")
show()

print((data[~0]<7.815).mean())

plot([5.991]*len(data[~1]))
plot(data[~1])
title("NIS Lidar")
show()
print((data[~1]<5.991).mean())
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 1.0
# 0.96

# %%
plot(data[0],data[1], label="Filter")
plot(data[7],data[6], label="Raw")
legend()
